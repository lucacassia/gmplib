# %%
from gmplib import *

# %%
N = 3
d = 2
X = [tensor([p[1] if j==i else p.one() for j in range(N)]) for i in range(N)]

# %%
sum(prod(b_lambda(lam[i]) for i in range(len(lam)))*tensor([iGMP(lam),GMP(lam)]) for lam in mPartitions(N,d)) == s[d]((1-t)/(1-q)*sum(tensor([X[N-i-1],(1-q3)*sum(X[j] for j in range(i))+X[i]]) for i in range(N)))
# Out:
# True
